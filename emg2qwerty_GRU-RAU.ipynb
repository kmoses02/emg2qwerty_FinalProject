# %% [markdown]
# # **Setup**

# %% [markdown]
# Mount drive

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Clone Repo, Install dependencies

# %%
# Clean workspace
# %cd /content
# !rm -rf emg2qwerty_FinalProject

# Clone repo
# !git clone https://github.com/kmoses02/emg2qwerty_FinalProject.git
# %cd emg2qwerty_FinalProject

# Checkout GRU branch
# !git checkout GRU-RAU

# Install dependencies
# !pip install -q -r requirements.txt
# !pip install -q -e .

# !git status
print("Setup complete")
# Out:
# /content
# Cloning into 'emg2qwerty_FinalProject'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 215 (delta 79), reused 51 (delta 44), pack-reused 75 (from 3)
# Receiving objects: 100% (215/215), 33.59 MiB | 24.62 MiB/s, done.
# Resolving deltas: 100% (80/80), done.
# Filtering content: 100% (17/17), 1.00 GiB | 48.82 MiB/s, done.
# /content/emg2qwerty_FinalProject
# Branch 'GRU-RAU' set up to track remote branch 'GRU-RAU' from 'origin'.
# Switched to a new branch 'GRU-RAU'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
# On branch GRU-RAU
# Your branch is up to date with 'origin/GRU-RAU'.
#
# nothing to commit, working tree clean
# Setup complete

# %% [markdown]
# ⚠️ After installing requirements, restart the runtime once before continuing.

# %% [markdown]
# # **Data**

# %% [markdown]
# Copy dataset from Drive to local runtime

# %%
from pathlib import Path
import shutil

DRIVE_ROOT = Path("/content/drive/MyDrive/C247A/C247A-Final_Project")
DRIVE_DATA = DRIVE_ROOT / "Dataset"
LOCAL_DATA = Path("/content/emg2qwerty_data")
REPO_DIR = Path("/content/emg2qwerty_FinalProject")

print("Drive dataset:", DRIVE_DATA)
print("Local dataset:", LOCAL_DATA)
print("Drive exists:", DRIVE_DATA.exists())

if LOCAL_DATA.exists():
    shutil.rmtree(LOCAL_DATA)

print("Copying dataset to local runtime...")
shutil.copytree(DRIVE_DATA, LOCAL_DATA)
print("Done.")
# Out:
# Drive dataset: /content/drive/MyDrive/C247A/C247A-Final_Project/Dataset
# Local dataset: /content/emg2qwerty_data
# Drive exists: True
# Copying dataset to local runtime...
# Done.

# %% [markdown]
# Copy dataset from Drive to local runtime using Smylink

# %%
# %cd /content/emg2qwerty_FinalProject
# !rm -rf data
# !ln -s /content/emg2qwerty_data data
# !ls -l .
# Out:
# /content/emg2qwerty_FinalProject
# total 148
# -rw-r--r-- 1 root root  3537 Mar  8 19:41 CODE_OF_CONDUCT.md
# -rw-r--r-- 1 root root  4004 Mar  8 19:41 Colab_setup.ipynb
# drwxr-xr-x 9 root root  4096 Mar  8 19:42 config
# -rw-r--r-- 1 root root   598 Mar  8 19:41 CONTRIBUTING.md
# lrwxrwxrwx 1 root root    24 Mar  8 19:45 data -> /content/emg2qwerty_data
# drwxr-xr-x 3 root root  4096 Mar  8 19:43 emg2qwerty
# drwxr-xr-x 2 root root  4096 Mar  8 19:42 emg2qwerty.egg-info
# -rw-r--r-- 1 root root 67683 Mar  8 19:42 emg2qwerty_GRU.ipynb
# -rw-r--r-- 1 root root  1066 Mar  8 19:41 environment.yml
# -rw-r--r-- 1 root root 20849 Mar  8 19:41 LICENSE
# drwxr-xr-x 5 root root  4096 Mar  8 19:42 models
# -rw-r--r-- 1 root root  6728 Mar  8 19:41 README.md
# -rw-r--r-- 1 root root   600 Mar  8 19:41 requirements.txt
# drwxr-xr-x 3 root root  4096 Mar  8 19:41 scripts
# -rw-r--r-- 1 root root   585 Mar  8 19:41 setup.cfg
# -rw-r--r-- 1 root root   567 Mar  8 19:41 setup.py

# %% [markdown]
# # **Sanity Checks**

# %% [markdown]
# **Verify data**

# %%
from pathlib import Path

DATA_DIR = Path("/content/emg2qwerty_FinalProject/data")
files = sorted(DATA_DIR.glob("*.hdf5"))

print("Total files:", len(files))
for f in files:
    print(f.name, round(f.stat().st_size / 1e6, 1), "MB")
# Out:
# Total files: 18
# 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 323.7 MB
# 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 296.5 MB
# 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 306.7 MB
# 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 255.2 MB
# 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 262.5 MB
# 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 255.3 MB
# 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 244.9 MB
# 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 231.6 MB
# 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 244.0 MB
# 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 290.1 MB
# 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 283.5 MB
# 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 277.3 MB
# 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 237.7 MB
# 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 247.4 MB
# 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 239.7 MB
# 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 237.8 MB
# 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 247.6 MB
# 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5 243.9 MB

# %% [markdown]
# This prints the Hydra config without training.

# %%
# %cd /content/emg2qwerty_FinalProject

# !python -m emg2qwerty.train --cfg job user="single_user" | head -n 140
# Out:
# /content/emg2qwerty_FinalProject
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# model:
#   _target_: emg2qwerty.lightning.GRUCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   hidden_size: 256
#   num_layers: 2
#   dropout: 0.1
#   bidirectional: true
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 150
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
# loggers:
# - _target_: pytorch_lightning.loggers.CSVLogger
#   save_dir: ${hydra:runtime.output_dir}
#   name: csv_logs
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200

# %% [markdown]
# **Test 'modules.py'**

# %%
import torch
from emg2qwerty.modules import GRUEncoder

x = torch.randn(100, 8, 768)   # (T, N, C) example
model = GRUEncoder(num_features=768, hidden_size=256, num_layers=2, bidirectional=True)

y = model(x)
print("input shape :", x.shape)
print("output shape:", y.shape)
# Out:
# input shape : torch.Size([100, 8, 768])
# output shape: torch.Size([100, 8, 768])

# %% [markdown]
# **Test 'lightning.py'**

# %%
# !python -c "from emg2qwerty.lightning import GRUCTCModule; print('GRUCTCModule import ok')"
# Out:
# GRUCTCModule import ok

# %% [markdown]
# **Test 'TemporalAttention'**

# %%
import torch
from emg2qwerty.modules import GRUEncoder, TemporalAttention

x = torch.randn(100, 8, 768)  # (T, N, C)

gru = GRUEncoder(
    num_features=768,
    hidden_size=256,
    num_layers=2,
    dropout=0.1,
    bidirectional=True,
)

attn = TemporalAttention(num_features=768, dropout=0.1)

y = gru(x)
z = attn(y)

print("input shape :", x.shape)
print("after GRU   :", y.shape)
print("after attn  :", z.shape)
# Out:
# input shape : torch.Size([100, 8, 768])
# after GRU   : torch.Size([100, 8, 768])
# after attn  : torch.Size([100, 8, 768])

# %%
# !python -m py_compile /content/emg2qwerty_FinalProject/emg2qwerty/lightning.py

# %%
# !python -c "from emg2qwerty.lightning import GRUCTCModule; print('GRUCTCModule import ok')"
# Out:
# GRUCTCModule import ok

# %% [markdown]
# # **TRAINING**

# %% [markdown]
# Define run metadata

# %%
from datetime import datetime

# Hyperparameters for this run
HIDDEN_SIZE = 512                 # Try 128 / 256 / 512 / 768
NUM_LAYERS = 3                    # Try 1 / 2 / 3
DROPOUT = 0.1                     # Try 0.1 / 0.2 / 0.3
BIDIRECTIONAL = True
LR = 0.001                        # Try 0.0003 / 0.0005 / 0.001 / 0.003
BATCH_SIZE = 32                   # Try 16 / 32 / 64
MAX_EPOCHS = 50                    # Try 50  / 100 /

# Build short tags
drop_tag = str(DROPOUT).replace(".", "")
bi_tag = "bi" if BIDIRECTIONAL else "uni"
lr_tag = f"{LR:.0e}".replace("-", "m")   # 0.001 -> 1e-03 -> 1em03

# Automatic run name
RUN_NAME = f"gru_h{HIDDEN_SIZE}_l{NUM_LAYERS}_d{drop_tag}_{bi_tag}_lr{lr_tag}_b{BATCH_SIZE}_e{MAX_EPOCHS}"

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
RUN_DIR = f"/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/{timestamp}_{RUN_NAME}"

print("RUN_NAME:", RUN_NAME)
print("RUN_DIR :", RUN_DIR)
# Out:
# RUN_NAME: gru_h512_l3_d01_bi_lr1em03_b32_e50
# RUN_DIR : /content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/2026-03-08_21-52-32_gru_h512_l3_d01_bi_lr1em03_b32_e50

# %% [markdown]
# Run 1-epoch test

# %%
# %cd /content/emg2qwerty_FinalProject

# !python -m emg2qwerty.train \
# user="single_user" \
# trainer.accelerator=gpu \
# trainer.devices=1 \
# trainer.max_epochs=1 \
# hydra.run.dir="$RUN_DIR"

# %% [markdown]
# **Full training run**

# %%
# %cd /content/emg2qwerty_FinalProject

# !python -m emg2qwerty.train \
user="single_user" \
trainer.accelerator=gpu \
trainer.devices=1 \
trainer.max_epochs=$MAX_EPOCHS \
model.hidden_size=$HIDDEN_SIZE \
model.num_layers=$NUM_LAYERS \
model.dropout=$DROPOUT \
model.bidirectional=$BIDIRECTIONAL \
optimizer.lr=$LR \
batch_size=$BATCH_SIZE \
hydra.run.dir="$RUN_DIR"
# Out:
# /content/emg2qwerty_FinalProject
# [2026-03-08 21:52:43,994][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# model:
#   _target_: emg2qwerty.lightning.GRUCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   hidden_size: 512
#   num_layers: 3
#   dropout: 0.1
#   bidirectional: true
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 50
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
# loggers:
# - _target_: pytorch_lightning.loggers.CSVLogger
#   save_dir: ${hydra:runtime.output_dir}
#   name: csv_logs
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
#
# Global seed set to 1501
# [2026-03-08 21:52:43,997][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.GRUCTCModule', 'in_features': 528, 'mlp_features': [384], 'hidden_size': 512, 'num_layers': 3, 'dropout': 0.1, 'bidirectional': True}
# [2026-03-08 21:52:44,168][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# [2026-03-08 21:52:45,506][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# [2026-03-08 21:52:45,506][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 14.7 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 14.7 M    Trainable params
# 0         Non-trainable params
# 14.7 M    Total params
# 58.645    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]/usr/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=43644) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Epoch 0:  94% 120/127 [00:26<00:01,  4.58it/s, loss=174, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 0: 100% 127/127 [00:27<00:00,  4.56it/s, loss=174, v_num=0]
# Epoch 0: 100% 127/127 [00:27<00:00,  4.56it/s, loss=174, v_num=0]Epoch 0, global step 120: 'val/CER' reached 1785.64465 (best 1785.64465), saving model to '/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/2026-03-08_21-52-32_gru_h512_l3_d01_bi_lr1em03_b32_e50/checkpoints/epoch=0-step=120.ckpt' as top 1
# Epoch 1:  94% 120/127 [00:24<00:01,  4.95it/s, loss=3.65, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 1: 100% 127/127 [00:25<00:00,  4.92it/s, loss=3.65, v_num=0]
# Epoch 1: 100% 127/127 [00:25<00:00,  4.92it/s, loss=3.65, v_num=0]Epoch 1, global step 240: 'val/CER' reached 100.00000 (best 100.00000), saving model to '/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/2026-03-08_21-52-32_gru_h512_l3_d01_bi_lr1em03_b32_e50/checkpoints/epoch=1-step=240.ckpt' as top 1
# Epoch 2:  94% 120/127 [00:26<00:01,  4.48it/s, loss=3.41, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 2: 100% 127/127 [00:28<00:00,  4.46it/s, loss=3.41, v_num=0]
# Epoch 2: 100% 127/127 [00:28<00:00,  4.46it/s, loss=3.41, v_num=0]Epoch 2, global step 360: 'val/CER' was not in top 1
# Epoch 3:  94% 120/127 [00:27<00:01,  4.34it/s, loss=3.29, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 3: 100% 127/127 [00:29<00:00,  4.35it/s, loss=3.29, v_num=0]
# Epoch 3: 100% 127/127 [00:29<00:00,  4.35it/s, loss=3.29, v_num=0]Epoch 3, global step 480: 'val/CER' was not in top 1
# Epoch 4:  94% 120/127 [00:24<00:01,  4.98it/s, loss=3.28, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 4: 100% 127/127 [00:25<00:00,  4.93it/s, loss=3.28, v_num=0]
# Epoch 4: 100% 127/127 [00:25<00:00,  4.93it/s, loss=3.28, v_num=0]Epoch 4, global step 600: 'val/CER' was not in top 1
# Epoch 5:  94% 120/127 [00:25<00:01,  4.75it/s, loss=3.26, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.72it/s, loss=3.26, v_num=0]
# Epoch 5: 100% 127/127 [00:26<00:00,  4.72it/s, loss=3.26, v_num=0]Epoch 5, global step 720: 'val/CER' was not in top 1
# Epoch 6:  94% 120/127 [00:24<00:01,  4.96it/s, loss=3.16, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 6: 100% 127/127 [00:25<00:00,  4.93it/s, loss=3.16, v_num=0]
# Epoch 6: 100% 127/127 [00:25<00:00,  4.93it/s, loss=3.16, v_num=0]Epoch 6, global step 840: 'val/CER' was not in top 1
# Epoch 7:  94% 120/127 [00:24<00:01,  4.98it/s, loss=3.08, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 7: 100% 127/127 [00:25<00:00,  4.95it/s, loss=3.08, v_num=0]
# Epoch 7: 100% 127/127 [00:25<00:00,  4.95it/s, loss=3.08, v_num=0]Epoch 7, global step 960: 'val/CER' was not in top 1
# Epoch 8:  94% 120/127 [00:26<00:01,  4.53it/s, loss=3, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 8: 100% 127/127 [00:27<00:00,  4.54it/s, loss=3, v_num=0]
# Epoch 8: 100% 127/127 [00:27<00:00,  4.54it/s, loss=3, v_num=0]Epoch 8, global step 1080: 'val/CER' was not in top 1
# Epoch 9:  94% 120/127 [00:24<00:01,  4.95it/s, loss=2.86, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch
v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 45: 100% 127/127 [00:26<00:00,  4.85it/s, loss=0.394, v_num=0]
# Epoch 45: 100% 127/127 [00:26<00:00,  4.85it/s, loss=0.394, v_num=0]Epoch 45, global step 5520: 'val/CER' was not in top 1
# Epoch 46:  94% 120/127 [00:24<00:01,  4.97it/s, loss=0.374, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 46: 100% 127/127 [00:25<00:00,  4.94it/s, loss=0.374, v_num=0]
# Epoch 46: 100% 127/127 [00:25<00:00,  4.94it/s, loss=0.374, v_num=0]Epoch 46, global step 5640: 'val/CER' reached 17.94417 (best 17.94417), saving model to '/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/2026-03-08_21-52-32_gru_h512_l3_d01_bi_lr1em03_b32_e50/checkpoints/epoch=46-step=5640.ckpt' as top 1
# Epoch 47:  94% 120/127 [00:25<00:01,  4.65it/s, loss=0.376, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 47: 100% 127/127 [00:27<00:00,  4.64it/s, loss=0.376, v_num=0]
# Epoch 47: 100% 127/127 [00:27<00:00,  4.64it/s, loss=0.376, v_num=0]Epoch 47, global step 5760: 'val/CER' reached 17.70049 (best 17.70049), saving model to '/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU-RAU/2026-03-08_21-52-32_gru_h512_l3_d01_bi_lr1em03_b32_e50/checkpoints/epoch=47-step=5760.ckpt' as top 1
# Epoch 48:  94% 120/127 [00:24<00:01,  4.95it/s, loss=0.364, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 48: 100% 127/127 [00:25<00:00,  4.91it/s, loss=0.364, v_num=0]
# Epoch 48: 100% 127/127 [00:25<00:00,  4.91it/s, loss=0.364, v_num=0]Epoch 48, global step 5880: 'val/CER' was not in top 1
# Epoch 49:  94% 120/127 [00:23<00:01,  5.01it/s, loss=0.354, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/7 [00:00<?, ?it/s]
# Epoch 49: 100% 127/127 [00:25<00:00,  4.97it/s, loss=0.354, v_num=0]
# Epoch 49: 100% 127/127 [00:25<00:00,  4.97it/s, loss=0.354, v_num=0]Epoch 49, global step 6000: 'val/CER' was not in top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100% 127/127 [00:26<00:00,  4.86it/s, loss=0.354, v_num=0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# # **TESTING**

# %% [markdown]
# Find available checkpoints

# %%
# import glob
# import os

# CKPT_ROOT = "/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU"

# ckpts = sorted(
#     glob.glob(f"{CKPT_ROOT}/**/*.ckpt", recursive=True),
#     key=os.path.getmtime
# )

# print(f"Found {len(ckpts)} checkpoint(s):")
# for c in ckpts[-20:]:
#     print(c)

# %% [markdown]
# **Pick the checkpoint to evaluate**

# %% [markdown]
# Option A: Manually paste a checkpoint path

# %%
# CHECKPOINT = "/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU/PUT_RUN_FOLDER_HERE/checkpoints/last.ckpt"
# print("Using checkpoint:", CHECKPOINT)

# %% [markdown]
# Option B: Automatically choose the newest checkpoint

# %%
# import glob
# import os

# ckpts = sorted(
#     glob.glob("/content/drive/MyDrive/C247A/C247A-Final_Project/outputs-GRU/**/*.ckpt", recursive=True),
#     key=os.path.getmtime
# )

# assert ckpts, "No checkpoints found."
# CHECKPOINT = ckpts[-1]
# print("Using newest checkpoint:", CHECKPOINT)

# %% [markdown]
# Validate the checkpoint path before running

# %%
# from pathlib import Path

# ckpt_path = Path(CHECKPOINT)
# assert ckpt_path.exists(), f"Checkpoint not found: {ckpt_path}"
# print("Checkpoint exists ✅")

# %% [markdown]
# Run testing / evaluation

# %%
# %cd /content/emg2qwerty_FinalProject

# !python -m emg2werty.train \
# user="single_user" \
# checkpoint="$CHECKPOINT" \
# train=False \
# trainer.accelerator=gpu \
# trainer.devices=1 \
# decoder=ctc_greedy

# %% [markdown]
# Optional: evaluate with a custom output folder

# %%
# TEST_RUN_DIR = "/content/drive/MyDrive/C247A/C247A-Final_Project/test-runs/manual_eval"

# !python -m emg2werty.train \
# user="single_user" \
# checkpoint="$CHECKPOINT" \
# train=False \
# trainer.accelerator=gpu \
# trainer.devices=1 \
# decoder=ctc_greedy \
# hydra.run.dir="$TEST_RUN_DIR"

# %% [markdown]
# # **Results**

# %% [markdown]
# Load metrics and config

# %%
import glob
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from omegaconf import OmegaConf

run_path = Path(RUN_DIR)
assert run_path.exists(), f"Run directory not found: {RUN_DIR}"

metrics_files = glob.glob(str(run_path / "csv_logs" / "**" / "metrics.csv"), recursive=True)
assert metrics_files, f"No metrics.csv found under {run_path / 'csv_logs'}"

metrics_file = metrics_files[0]

config_files = glob.glob(str(run_path / "**" / "*.yaml"), recursive=True)
cfg = None
cfg_path = None
for f in config_files:
    try:
        maybe_cfg = OmegaConf.load(f)
        if "model" in maybe_cfg:
            cfg = maybe_cfg
            cfg_path = f
            break
    except Exception:
        pass

assert cfg is not None, "Could not find config with model settings."

df = pd.read_csv(metrics_file)

print("Using metrics file:", metrics_file)
print("Using config file:", cfg_path)
print("Columns:", df.columns.tolist())

# %% [markdown]
# Save summary JSON

# %%
model_cfg = cfg.model
trainer_cfg = cfg.trainer

summary = {
    "run_name": RUN_NAME,
    "run_dir": RUN_DIR,
    "model_target": model_cfg.get("_target_", "unknown"),
    "in_features": model_cfg.get("in_features", "n/a"),
    "mlp_features": list(model_cfg.get("mlp_features", [])),
    "hidden_size": model_cfg.get("hidden_size", "n/a"),
    "num_layers": model_cfg.get("num_layers", "n/a"),
    "dropout": model_cfg.get("dropout", "n/a"),
    "bidirectional": model_cfg.get("bidirectional", "n/a"),
    "batch_size": cfg.get("batch_size", "n/a"),
    "lr": cfg.optimizer.get("lr", "n/a") if "optimizer" in cfg else "n/a",
    "max_epochs": trainer_cfg.get("max_epochs", "n/a"),
}

if "val/CER" in df.columns:
    vals = df["val/CER"].dropna()
    if len(vals) > 0:
        summary["best_val_CER"] = float(vals.min())

if "test/CER" in df.columns:
    vals = df["test/CER"].dropna()
    if len(vals) > 0:
        summary["final_test_CER"] = float(vals.iloc[-1])

with open(run_path / "summary.json", "w") as f:
    json.dump(summary, f, indent=2)

print("Saved:", run_path / "summary.json")
print(summary)

# %% [markdown]
# **CER plot**

# %%
cer_df = df[["epoch", "val/CER"]].dropna()

hyper_text = (
    f"Model: {summary['model_target'].split('.')[-1]}\n"
    f"in_features: {summary['in_features']}\n"
    f"mlp_features: {summary['mlp_features']}\n"
    f"hidden_size: {summary['hidden_size']}\n"
    f"num_layers: {summary['num_layers']}\n"
    f"dropout: {summary['dropout']}\n"
    f"bidirectional: {summary['bidirectional']}\n"
    f"batch_size: {summary['batch_size']}\n"
    f"lr: {summary['lr']}\n"
    f"max_epochs: {summary['max_epochs']}\n"
    f"run: {run_path.name}"
)

plt.figure(figsize=(10, 6))
plt.plot(cer_df["epoch"], cer_df["val/CER"], marker="o")
plt.xlabel("Epoch")
plt.ylabel("Validation CER")
plt.title("Validation CER vs Epoch")
plt.grid(True)

plt.gcf().text(
    0.72, 0.5, hyper_text,
    fontsize=10,
    bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray")
)

plt.tight_layout(rect=[0, 0, 0.72, 1])

cer_plot_path = run_path / "val_cer_plot.png"
plt.savefig(cer_plot_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved plot to:", cer_plot_path)
print("Best val/CER:", summary.get("best_val_CER", "n/a"))
print("Final test/CER:", summary.get("final_test_CER", "n/a"))

# %% [markdown]
# **Loss plot**

# %%
plt.figure(figsize=(8, 5))

if "train/loss" in df.columns:
    train_loss = df[["epoch", "train/loss"]].dropna()
    plt.plot(train_loss["epoch"], train_loss["train/loss"], marker="o", label="train/loss")

if "val/loss" in df.columns:
    val_loss = df[["epoch", "val/loss"]].dropna()
    plt.plot(val_loss["epoch"], val_loss["val/loss"], marker="o", label="val/loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.legend()
plt.grid(True)

loss_plot_path = run_path / "loss_plot.png"
plt.savefig(loss_plot_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved plot to:", loss_plot_path)

# %% [markdown]
# # **Update Repo**

# %% [markdown]
# Load Secret Token + define constants

# %%
from google.colab import userdata
from pathlib import Path

github_token = userdata.get("GitHub_Key")
assert github_token, "Missing GitHub_Key in Colab Secrets"

# This must match the GitHub account that owns the repo
github_repo_owner = "kmoses02"

# This is just commit metadata
git_name = "Justin Calderon"
git_email = "justinfcalderon@gmail.com"

REPO_DIR = Path("/content/emg2qwerty_FinalProject")
NOTEBOOK_SRC = Path("/content/drive/MyDrive/C247A/C247A-Final_Project/emg2qwerty_GRU-RAU.ipynb")
NOTEBOOK_DST = REPO_DIR / "emg2qwerty_GRU-RAU.ipynb"
BRANCH_NAME = "GRU-RAU"

print("Token loaded:", github_token is not None)
print("Repo owner:", github_repo_owner)

# %% [markdown]
# Sync notebook into repo + set git identity

# %%
import shutil
import os

assert REPO_DIR.exists(), f"Repo not found: {REPO_DIR}"
assert NOTEBOOK_SRC.exists(), f"Notebook not found: {NOTEBOOK_SRC}"

shutil.copy2(NOTEBOOK_SRC, NOTEBOOK_DST)
print(f"Copied notebook to repo: {NOTEBOOK_DST}")

os.chdir(REPO_DIR)
print("CWD:", os.getcwd())

# !git config user.name "$git_name"
# !git config user.email "$git_email"
# !git branch --show-current
# !git status

# %% [markdown]
# Stage + commit changes

# %%
# !git add emg2qwerty
# !git add config
# !git add emg2qwerty_GRU-RAU.ipynb
# !git status

# %% [markdown]
# Change the message each time:

# %%
COMMIT_MSG = "Add GRU + temporal attention (RAU-inspired) experiment"
# !git commit -m "$COMMIT_MSG"

# %% [markdown]
# Push safely, then restore clean remote

# %%
repo_url = f"https://{github_repo_owner}:{github_token}@github.com/{github_repo_owner}/emg2qwerty_FinalProject.git"
clean_url = f"https://github.com/{github_repo_owner}/emg2qwerty_FinalProject.git"

# !git remote set-url origin "$repo_url"
# !git push origin "$BRANCH_NAME"
# !git remote set-url origin "$clean_url"

print("Push complete.")
